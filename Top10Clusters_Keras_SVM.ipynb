# %%
import pandas as pd
import numpy as np
import pickle
import time
from datetime import date

import matplotlib.pyplot as plt
import seaborn as sns

import os
import gc
import zipfile
import io

# %%
import tensorflow as tf
import keras
from scikeras.wrappers import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout

from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.model_selection import KFold,train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline
# Out:
# WARNING:tensorflow:From c:\Users\Dell\Desktop\RBS\Algorithmic Machine Learning\Project\Code\venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train = pd.read_csv('final/final.csv')
train.head()
# Out:
#    site_name  posa_continent  user_location_country  user_location_region  \
# 0          2               3                     66                   348
# 1          2               3                     66                   318
# 2         30               4                    195                   548
# 3         30               4                    195                   991
# 4          2               3                     66                   462
#
#    user_location_city  orig_destination_distance  user_id  is_mobile  \
# 0               48862                          1       12          0
# 1               52078                          3      756          0
# 2               56440                          3     1048          0
# 3               47725                          3     1048          0
# 4               41898                          1     1482          0
#
#    is_package  channel  ...         0         1         2         3         4  \
# 0           1        9  ...  2.168369 -0.061117  0.723259 -0.254974  0.258598
# 1           1        4  ...  1.081223 -0.472179 -0.336746  0.197516  0.078124
# 2           1        9  ...  0.354725  0.776146 -0.230059  0.319022  0.138679
# 3           0        9  ...  0.739997 -0.263293 -0.169228  0.014864 -0.019029
# 4           1        1  ...  0.653804  0.306180  0.006980 -0.212106 -0.020089
#
#           5         6         7         8         9
# 0  0.862231  0.864002  0.177810 -0.043409 -0.065274
# 1  0.123741 -0.185023 -0.006560  0.071988 -0.086640
# 2  0.122441 -0.190630  0.179111  0.252992 -0.125460
# 3 -0.051152  0.003836  0.314507  0.090583 -0.201417
# 4  0.003922 -0.167449 -0.051248 -0.155864 -0.055948
#
# [5 rows x 39 columns]

# %%
train['hotel_cluster'].value_counts()
# Out:
# hotel_cluster
# 91    100388
# 48     69653
# 42     61271
# 59     54680
# 28     54301
#        ...
# 35      5811
# 92      5593
# 53      3977
# 27      2303
# 74      2219
# Name: count, Length: 100, dtype: int64

# %% [markdown]
# * Since our previous ML Models have been performing poorly, we decide to move to deep learning in order to achieve better performance.
# * To achieve this, we consider the top 10 common clusters from our cleaned dataset

# %%
most_common_clusters = list(train.hotel_cluster.value_counts().head(10).index)
most_common_clusters
# Out:
# [91, 48, 42, 59, 28, 16, 18, 95, 50, 21]

# %%
train = train.loc[train['hotel_cluster'].isin(most_common_clusters)]

# %%
print("Length of new training dataset:", len(train))
# Out:
# Length of new training dataset: 568972

# %%
train['hotel_cluster'].replace([91, 48, 42, 59, 28, 16, 18, 95, 50, 21],  
                               ['ninety-one','forty-eight','forty-two','fifty-nine','twenty-eight', 'sixteen',
                                'eighteen','ninety-five','fifty','twenty-one'], 
                               inplace=True)
train['hotel_cluster'].value_counts()
# Out:
# hotel_cluster
# ninety-one      100388
# forty-eight      69653
# forty-two        61271
# fifty-nine       54680
# twenty-eight     54301
# sixteen          46784
# eighteen         46767
# ninety-five      46755
# fifty            45915
# twenty-one       42458
# Name: count, dtype: int64

# %%
X = train.drop(['hotel_cluster'], axis=1)
y_target = train['hotel_cluster']

# %%
from sklearn.preprocessing import LabelEncoder

# encode class values as integers
encoder = LabelEncoder()
encoder.fit(y_target)
encoded_y = encoder.transform(y_target)
# convert integers to dummy variables (i.e. one hot encoded)
y = keras.utils.to_categorical(encoded_y)

# %%
print(encoded_y)
# Out:
# [5 5 5 ... 6 4 4]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# scales data between 0 and 1
X_train = keras.utils.normalize(X_train, axis=1)  
X_test = keras.utils.normalize(X_test, axis=1)

# %%
X_train.shape
# Out:
# (455177, 38)

# %% [markdown]
# #### KERAS MODEL

# %%
def c_model():

  model = Sequential()
  model.add(Dense(2048, activation='relu', input_dim=38))
  # model.add(Dense(1024, activation='relu'))
  # model.add(Dropout(0.25))
  model.add(Dense(512, activation='relu'))
  # model.add(Dropout(0.25))
  model.add(Dense(256, activation='relu'))
  # model.add(Dropout(0.25))
  # model.add(Dense(128, activation='relu'))
  # model.add(Dropout(0.25))
  model.add(Dense(64, activation='relu'))
  # model.add(Dropout(0.5))
  model.add(Dense(10, activation='softmax'))
  
  model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
  
  return model

# %%
model = KerasClassifier(build_fn=c_model, epochs=100, batch_size=128)

# %%
model.fit(X_train, y_train)
# Out:
# WARNING:tensorflow:From c:\Users\Dell\Desktop\RBS\Algorithmic Machine Learning\Project\Code\venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# c:\Users\Dell\Desktop\RBS\Algorithmic Machine Learning\Project\Code\venv\lib\site-packages\scikeras\wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# WARNING:tensorflow:From c:\Users\Dell\Desktop\RBS\Algorithmic Machine Learning\Project\Code\venv\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\Dell\Desktop\RBS\Algorithmic Machine Learning\Project\Code\venv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Dell\Desktop\RBS\Algorithmic Machine Learning\Project\Code\venv\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3557/3557 [==============================] - 51s 14ms/step - loss: 2.2626 - accuracy: 0.1768
# Epoch 2/100
# 3557/3557 [==============================] - 59s 17ms/step - loss: 2.2306 - accuracy: 0.1842
# Epoch 3/100
# 3557/3557 [==============================] - 57s 16ms/step - loss: 2.1959 - accuracy: 0.2009
# Epoch 4/100
# 3557/3557 [==============================] - 56s 16ms/step - loss: 2.1807 - accuracy: 0.2069
# Epoch 5/100
# 3557/3557 [==============================] - 57s 16ms/step - loss: 2.1733 - accuracy: 0.2101
# Epoch 6/100
# 3557/3557 [==============================] - 61s 17ms/step - loss: 2.1682 - accuracy: 0.2122
# Epoch 7/100
# 3557/3557 [==============================] - 52s 15ms/step - loss: 2.1621 - accuracy: 0.2136
# Epoch 8/100
# 3557/3557 [==============================] - 49s 14ms/step - loss: 2.1573 - accuracy: 0.2152
# Epoch 9/100
# 3557/3557 [==============================] - 54s 15ms/step - loss: 2.1524 - accuracy: 0.2168
# Epoch 10/100
# 3557/3557 [==============================] - 50s 14ms/step - loss: 2.1473 - accuracy: 0.2186
# Epoch 11/100
# 3557/3557 [==============================] - 46s 13ms/step - loss: 2.1449 - accuracy: 0.2192
# Epoch 12/100
# 3557/3557 [==============================] - 45s 13ms/step - loss: 2.1396 - accuracy: 0.2207
# Epoch 13/100
# 3557/3557 [==============================] - 46s 13ms/step - loss: 2.1354 - accuracy: 0.2217
# Epoch 14/100
# 3557/3557 [==============================] - 49s 14ms/step - loss: 2.1346 - accuracy: 0.2221
# Epoch 15/100
# 3557/3557 [==============================] - 56s 16ms/step - loss: 2.1308 - accuracy: 0.2226
# Epoch 16/100
# 3557/3557 [==============================] - 62s 17ms/step - loss: 2.1275 - accuracy: 0.2235
# Epoch 17/100
# 3557/3557 [==============================] - 61s 17ms/step - loss: 2.1247 - accuracy: 0.2246
# Epoch 18/100
# 3557/3557 [==============================] - 58s 16ms/step - loss: 2.1224 - accuracy: 0.2249
# Epoch 19/100
# 3557/3557 [==============================] - 59s 17ms/step - loss: 2.1209 - accuracy: 0.2254
# Epoch 20/100
# 3557/3557 [==============================] - 58s 16ms/step - loss: 2.1190 - accuracy: 0.2259
# Epoch 21/100
# 3557/3557 [==============================] - 59s 17ms/step - loss: 2.1175 - accuracy: 0.2257
# Epoch 22/100
# 3557/3557 [==============================] - 61s 17ms/step - loss: 2.1176 - accuracy: 0.2262
# Epoch 23/100
# 3557/3557 [==============================] - 58s 16ms/step - loss: 2.1148 - accuracy: 0.2265
# Epoch 24/100
# 3557/3557 [==============================] - 56s 16ms/step - loss: 2.1139 - accuracy: 0.2272
# Epoch 25/100
# 3557/3557 [==============================] - 58s 16ms/step - loss: 2.1140 - accuracy: 0.2275
# Epoch 26/100
# 3557/3557 [==============================] - 63s 18ms/step - loss: 2.1129 - accuracy: 0.2275
# Epoch 27/100
# 3557/3557 [==============================] - 59s 16ms/step - loss: 2.1111 - accuracy: 0.2277
# Epoch 28/100
# 3557/3557 [==============================] - 56s 16ms/step - loss: 2.1101 - accuracy: 0.2279
# Epoch 29/100
# 3557/3557 [==============================] - 59s 17ms/step - loss: 2.1067 - accuracy: 0.2289
# Epoch 30/100
# 3557/3557 [==============================] - 60s 17ms/step - loss: 2.1075 - accuracy: 0.2287
# Epoch 31/100
# 3557/3557 [==============================] - 57s 16ms/step - loss: 2.1065 - accuracy: 0.2291
# Epoch 32/100
# 3557/3557 [==============================] - 56s 16ms/step - loss: 2.1039 - accuracy: 0.2298
# Epoch 33/100
# 3557/3557 [==============================] - 54s 15ms/step - loss: 2.1043 - accuracy: 0.2294
# Epoch 34/100
# 3557/3557 [==============================] - 54s 15ms/step - loss: 2.1028 - accuracy: 0.2296
# Epoch 35/100
# 3557/3557 [==============================] - 57s 16ms/step - loss: 2.1017 - accuracy: 0.2302
# Epoch 36/100
# 3557/3557 [==============================] - 59s 16ms/step - loss: 2.1014 - accuracy: 0.2304
# Epoch 37/100
# 3557/3557 [==============================] - 57s 16ms/step - loss: 2.1006 - accuracy: 0.2300
# Epoch 38/100
# 3557/3557 [==============================] - 57s 16ms/step - loss: 2.0986 - accuracy: 0.2315
# Epoch 39/100
# 3557/3557 [==============================] - 55s 15ms/step - loss: 2.0981 - accuracy: 0.2310
# Epoch 40/100
# 3557/3557 [==============================] - 55s 15ms/step - loss: 2.0974 - accuracy: 0.2312
# Epoch 41/100
# 3557/3557 [==============================] - 57s 16ms/step - loss: 2.0969 - accuracy: 0.2315
# Epoch 42/100
# 3557/3557 [==============================] - 56s 16ms/step - loss: 2.0966 - accuracy: 0.2322
# Epoch 43/100
# 3557/3557 [==============================] - 57s 16ms/step - loss: 2.0958 - accuracy: 0.2321
# Epoch 44/100
# 3557/3557 [==============================] - 57s 16ms/step - loss: 2.0933 - accuracy: 0.2323
# Epoch 45/100
# 3557/3557 [==============================] - 59s 17ms/step - loss: 2.0942 - accuracy: 0.2318
# Epoch 46/100
# 3557/3557 [==============================] - 57s 16ms/step - loss: 2.0925 - accuracy: 0.2325
# Epoch 47/100
# 3557/3557 [==============================] - 54s 15ms/step - loss: 2.0922 - accuracy: 0.2328
# Epoch 48/100
# 3557/3557 [==============================] - 56s 16ms/step - loss: 2.0905 - accuracy: 0.2327
# Epoch 49/100
# 3557/3557 [==============================] - 53s 15ms/step - loss: 2.0915 - accuracy: 0.2330
# Epoch 50/100
# 3557/3557 [==============================] - 53s 15ms/step - loss: 2.0911 - accuracy: 0.2327
# Epoch 51/100
# 3557/3557 [==============================] - 52s 15ms/step - loss: 2.0877 - accuracy: 0.2335
# Epoch 52/100
# 3557/3557 [==============================] - 53s 15ms/step - loss: 2.0883 - accuracy: 0.2339
# Epoch 53/100
# 3557/3557 [==============================] - 52s 15ms/step - loss: 2.0868 - accuracy: 0.2338
# Epoch 54/100
# 3557/3557 [==============================] - 54s 15ms/step - loss: 2.0869 - accuracy: 0.2342
# Epoch 55/100
# 3557/3557 [==============================] - 52s 15ms/step - loss: 2.0870 - accuracy: 0.2341
# Epoch 56/100
# 3557/3557 [==============================] - 53s 15ms/step - loss: 2.0856 - accuracy: 0.2344
# Epoch 57/100
# 3557/3557 [==============================] - 54s 15ms/step - loss: 2.0841 - accuracy: 0.2356
# Epoch 58/100
# 3557/3557 [==============================] - 53s 15ms/step - loss: 2.0833 - accuracy: 0.2351
# Epoch 59/100
# 3557/3557 [==============================] - 54s 15ms/step - loss: 2.0833 - accuracy: 0.2354
# Epoch 60/100
# 3557/3557 [==============================] - 54s 15ms/step - loss: 2.0837 - accuracy: 0.2354
# Epoch 61/100
# 3557/3557 [==============================] - 52s 15ms/step - loss: 2.0823 - accuracy: 0.2351
# Epoch 62/100
# 3557/3557 [==============================] - 52s 15ms/step - loss: 2.0819 - accuracy: 0.2351
# Epoch 63/100
# 3557/3557 [==============================] - 57s 16ms/step - loss: 2.0820 - accuracy: 0.2354
# Epoch 64/100
# 3557/3557 [==============================] - 55s 15ms/step - loss: 2.0795 - accuracy: 0.2356
# Epoch 65/100
# 3557/3557 [==============================] - 54s 15ms/step - loss: 2.0811 - accuracy: 0.2359
# Epoch 66/100
# 3557/3557 [==============================] - 52s 15ms/step - loss: 2.

# 	warm_start=False
# 	random_state=None
# 	optimizer=rmsprop
# 	loss=None
# 	metrics=None
# 	batch_size=128
# 	validation_batch_size=None
# 	verbose=1
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=100
# 	class_weight=None
# )

# %% [markdown]
# ### Grid Search CV
#
# Tune batch size and epochs

# %%
model = KerasClassifier(build_fn=c_model)

batch_sizes = [128] #batch_size = 128
epochs = [30] #, 50, 100, 200]
parameters = {'epochs': epochs}
clf = GridSearchCV(model, parameters, cv=2)
clf.fit(X_train, y_train)
# Out:
# c:\Users\Dell\Desktop\RBS\Algorithmic Machine Learning\Project\Code\venv\lib\site-packages\scikeras\wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# Epoch 1/30
# 7113/7113 [==============================] - 90s 12ms/step - loss: 2.2661 - accuracy: 0.1757
# Epoch 2/30
# 7113/7113 [==============================] - 105s 15ms/step - loss: 2.2557 - accuracy: 0.1759
# Epoch 3/30
# 7113/7113 [==============================] - 89s 12ms/step - loss: 2.2402 - accuracy: 0.1769
# Epoch 4/30
# 7113/7113 [==============================] - 76s 11ms/step - loss: 2.2290 - accuracy: 0.1840
# Epoch 5/30
# 7113/7113 [==============================] - 74s 10ms/step - loss: 2.2093 - accuracy: 0.1943
# Epoch 6/30
# 7113/7113 [==============================] - 79s 11ms/step - loss: 2.1964 - accuracy: 0.2001
# Epoch 7/30
# 7113/7113 [==============================] - 96s 14ms/step - loss: 2.1878 - accuracy: 0.2032
# Epoch 8/30
# 7113/7113 [==============================] - 99s 14ms/step - loss: 2.1849 - accuracy: 0.2046
# Epoch 9/30
# 7113/7113 [==============================] - 99s 14ms/step - loss: 2.1796 - accuracy: 0.2070
# Epoch 10/30
# 7113/7113 [==============================] - 93s 13ms/step - loss: 2.1763 - accuracy: 0.2082
# Epoch 11/30
# 7113/7113 [==============================] - 88s 12ms/step - loss: 2.1712 - accuracy: 0.2102
# Epoch 12/30
# 7113/7113 [==============================] - 105s 15ms/step - loss: 2.1697 - accuracy: 0.2110
# Epoch 13/30
# 7113/7113 [==============================] - 94s 13ms/step - loss: 2.1671 - accuracy: 0.2112
# Epoch 14/30
# 7113/7113 [==============================] - 92s 13ms/step - loss: 2.1636 - accuracy: 0.2136
# Epoch 15/30
# 7113/7113 [==============================] - 89s 12ms/step - loss: 2.1619 - accuracy: 0.2131
# Epoch 16/30
# 7113/7113 [==============================] - 91s 13ms/step - loss: 2.1595 - accuracy: 0.2149
# Epoch 17/30
# 7113/7113 [==============================] - 90s 13ms/step - loss: 2.1567 - accuracy: 0.2152
# Epoch 18/30
# 7113/7113 [==============================] - 89s 12ms/step - loss: 2.1548 - accuracy: 0.2164
# Epoch 19/30
# 7113/7113 [==============================] - 88s 12ms/step - loss: 2.1528 - accuracy: 0.2171
# Epoch 20/30
# 7113/7113 [==============================] - 89s 13ms/step - loss: 2.1509 - accuracy: 0.2178
# Epoch 21/30
# 7113/7113 [==============================] - 70s 10ms/step - loss: 2.1500 - accuracy: 0.2182
# 14225/14225 [==============================] - 196s 14ms/step - loss: 2.1386 - accuracy: 0.2208
# Epoch 14/30
# 14225/14225 [==============================] - 191s 13ms/step - loss: 2.1363 - accuracy: 0.2213
# Epoch 15/30
# 14225/14225 [==============================] - 149s 10ms/step - loss: 2.1349 - accuracy: 0.2219
# Epoch 16/30
# 14225/14225 [==============================] - 156s 11ms/step - loss: 2.1311 - accuracy: 0.2228
# Epoch 17/30
# 14225/14225 [==============================] - 170s 12ms/step - loss: 2.1293 - accuracy: 0.2232
# Epoch 18/30
# 14225/14225 [==============================] - 171s 12ms/step - loss: 2.1270 - accuracy: 0.2241
# Epoch 19/30
# 14225/14225 [==============================] - 202s 14ms/step - loss: 2.1253 - accuracy: 0.2244
# Epoch 20/30
# 14225/14225 [==============================] - 203s 14ms/step - loss: 2.1232 - accuracy: 0.2251
# Epoch 21/30
# 14225/14225 [==============================] - 198s 14ms/step - loss: 2.1223 - accuracy: 0.2248
# Epoch 22/30
# 14225/14225 [==============================] - 193s 14ms/step - loss: 2.1205 - accuracy: 0.2253
# Epoch 23/30
# 14225/14225 [==============================] - 182s 13ms/step - loss: 2.1207 - accuracy: 0.2253
# Epoch 24/30
# 14225/14225 [==============================] - 190s 13ms/step - loss: 2.1192 - accuracy: 0.2250
# Epoch 25/30
# 14225/14225 [==============================] - 206s 14ms/step - loss: 2.1175 - accuracy: 0.2259
# Epoch 26/30
# 14225/14225 [==============================] - 189s 13ms/step - loss: 2.1163 - accuracy: 0.2265
# Epoch 27/30
# 14225/14225 [==============================] - 170s 12ms/step - loss: 2.1140 - accuracy: 0.2267
# Epoch 28/30
# 14225/14225 [==============================] - 156s 11ms/step - loss: 2.1134 - accuracy: 0.2269
# Epoch 29/30
# 14225/14225 [==============================] - 206s 14ms/step - loss: 2.1138 - accuracy: 0.2270
# Epoch 30/30
# 14225/14225 [==============================] - 207s 15ms/step - loss: 2.1118 - accuracy: 0.2272
# GridSearchCV(cv=2,
#              estimator=KerasClassifier(build_fn=<function c_model at 0x000001FCE2BB4DC0>),
#              param_grid={'epochs': [30]})

# %%
print(clf.best_score_, clf.best_params_)
means = clf.cv_results_['mean_test_score']
parameters = clf.cv_results_['params']
for mean, parameter in zip(means, parameters):
  print(mean, parameter)
# Out:
# 0.21650477971486337 {'epochs': 30}
# 0.21650477971486337 {'epochs': 30}

# %% [markdown]
# ### SVM

# %%
X_svm_train, X_svm_test, y_svm_train, y_svm_test = train_test_split(X, y_target, test_size=0.2, random_state=1)

# %%
from sklearn import svm

clf = svm.SVC(kernel='rbf')
#Train the model using the training sets
clf.fit(X_svm_train, y_svm_train)

#Predict the response for test dataset
y_pred = clf.predict(X_svm_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

print("Accuracy:", accuracy_score(y_svm_test, y_pred))
print("Precision:",precision_score(y_svm_test, y_pred, average="micro"))
print("Recall:",recall_score(y_svm_test, y_pred,  average="micro"))
